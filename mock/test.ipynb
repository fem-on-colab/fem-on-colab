# %%
try:
    import BACKEND_LIBRARY_IN  # noqa: F401
except ImportError:
    import mock  # noqa: UP026
else:
    # !wget "https://PROJECT_NAME_IN.github.io/releases/mock-install.sh" -O "/tmp/mock-install.sh" && bash "/tmp/mock-install.sh"
    import mock  # noqa: UP026

# %%
assert mock.variable == 1
